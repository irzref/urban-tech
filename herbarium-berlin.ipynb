# %% [markdown]
# # Inspecting Dataset

# %%
import pandas as pd

test_df = pd.read_csv("../herbarium-berlin.csv", sep = '\t')
# Out:
# /root/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test_df.shape
# Out:
# (380276, 45)

# %%
print(len(test_df.columns))
list(test_df.columns)
# Out:
# 45
# ['gbifID',
#  'datasetKey',
#  'occurrenceID',
#  'kingdom',
#  'phylum',
#  'class',
#  'order',
#  'family',
#  'genus',
#  'species',
#  'infraspecificEpithet',
#  'taxonRank',
#  'scientificName',
#  'countryCode',
#  'locality',
#  'publishingOrgKey',
#  'decimalLatitude',
#  'decimalLongitude',
#  'coordinateUncertaintyInMeters',
#  'coordinatePrecision',
#  'elevation',
#  'elevationAccuracy',
#  'depth',
#  'depthAccuracy',
#  'eventDate',
#  'day',
#  'month',
#  'year',
#  'taxonKey',
#  'speciesKey',
#  'basisOfRecord',
#  'institutionCode',
#  'collectionCode',
#  'catalogNumber',
#  'recordNumber',
#  'identifiedBy',
#  'dateIdentified',
#  'license',
#  'rightsHolder',
#  'recordedBy',
#  'typeStatus',
#  'establishmentMeans',
#  'lastInterpreted',
#  'mediaType',
#  'issue']

# %%
test_df.iloc[:,0:3].head(10)
# Out:
#        gbifID                            datasetKey  \
# 0  1144558558  85714c48-f762-11e1-a439-00145eb45e9a
# 1  1144558559  85714c48-f762-11e1-a439-00145eb45e9a
# 2  1144558560  85714c48-f762-11e1-a439-00145eb45e9a
# 3  1144558561  85714c48-f762-11e1-a439-00145eb45e9a
# 4  1144558563  85714c48-f762-11e1-a439-00145eb45e9a
# 5  1144558564  85714c48-f762-11e1-a439-00145eb45e9a
# 6  1144558566  85714c48-f762-11e1-a439-00145eb45e9a
# 7  1144558567  85714c48-f762-11e1-a439-00145eb45e9a
# 8  1144558568  85714c48-f762-11e1-a439-00145eb45e9a
# 9  1144558569  85714c48-f762-11e1-a439-00145eb45e9a
#
#                                     occurrenceID
# 0    http://herbarium.bgbm.org/object/BW19937020
# 1    http://herbarium.bgbm.org/object/BW19937010
# 2    http://herbarium.bgbm.org/object/B200049406
# 3    http://herbarium.bgbm.org/object/B200011251
# 4    http://herbarium.bgbm.org/object/B100461080
# 5    http://herbarium.bgbm.org/object/B100630589
# 6  http://herbarium.bgbm.org/object/B200015631_b
# 7    http://herbarium.bgbm.org/object/B100630588
# 8    http://herbarium.bgbm.org/object/B100461077
# 9    http://herbarium.bgbm.org/object/B100461067

# %%
test_df.iloc[:,3:10].head(10)
# Out:
#    kingdom        phylum           class         order        family  \
# 0  Plantae  Tracheophyta  Polypodiopsida  Polypodiales  Aspleniaceae
# 1  Plantae  Tracheophyta  Polypodiopsida  Polypodiales  Aspleniaceae
# 2  Plantae  Tracheophyta  Polypodiopsida  Polypodiales   Athyriaceae
# 3  Plantae  Tracheophyta  Polypodiopsida  Polypodiales  Aspleniaceae
# 4  Plantae  Tracheophyta   Magnoliopsida     Asterales    Asteraceae
# 5  Plantae  Tracheophyta   Magnoliopsida   Magnoliales    Annonaceae
# 6  Plantae  Tracheophyta  Polypodiopsida  Polypodiales  Aspleniaceae
# 7  Plantae  Tracheophyta   Magnoliopsida   Magnoliales    Annonaceae
# 8  Plantae  Tracheophyta   Magnoliopsida     Asterales    Asteraceae
# 9  Plantae  Tracheophyta   Magnoliopsida     Asterales    Asteraceae
#
#              genus                   species
# 0        Asplenium       Asplenium onopteris
# 1        Asplenium       Asplenium onopteris
# 2        Diplazium      Diplazium rhoifolium
# 3        Asplenium        Asplenium virillae
# 4     Arctanthemum     Arctanthemum arcticum
# 5        Guatteria  Guatteria schomburgkiana
# 6        Asplenium   Asplenium alternifolium
# 7        Guatteria  Guatteria schomburgkiana
# 8  Leucanthemopsis    Leucanthemopsis alpina
# 9  Leucanthemopsis    Leucanthemopsis alpina

# %%
test_df.iloc[:,10:16].head(10)
# Out:
#   infraspecificEpithet taxonRank                           scientificName  \
# 0                  NaN   SPECIES          Asplenium acutum Bory ex Willd.
# 1                  NaN   SPECIES          Asplenium acutum Bory ex Willd.
# 2                  NaN   SPECIES               Diplazium rhoifolium Mett.
# 3                  NaN   SPECIES                Asplenium virillae Christ
# 4                  NaN   SPECIES       Arctanthemum arcticum (L.) Tzvelev
# 5                  NaN   SPECIES           Guatteria schomburgkiana Mart.
# 6                  NaN   SPECIES             Asplenium heufleri Reichardt
# 7                  NaN   SPECIES           Guatteria schomburgkiana Mart.
# 8                  NaN   SPECIES  Leucanthemopsis alpina (L.) V.H.Heywood
# 9                  NaN   SPECIES  Leucanthemopsis alpina (L.) V.H.Heywood
#
#   countryCode                                           locality  \
# 0          ES                                         Teneriffe.
# 1          ES                    Teneriffe a la forêt de Laguna.
# 2          GY                                       New Granada.
# 3          CR                          Candelaria, Alt.: 1600 m.
# 4         NaN                  Triostroff in Lapponia maxime or.
# 5          SR                                                NaN
# 6          IT  Rheinpreußen auf Devon Schiefer des Ahrthales....
# 7          SR                                              Para.
# 8          SK                                             Tatra.
# 9          IT                Lombardei. [?] in Monte Venerocolo.
#
#                        publishingOrgKey
# 0  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 1  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 2  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 3  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 4  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 5  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 6  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 7  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 8  57254bd0-8256-11d8-b7ed-b8a03c50a862
# 9  57254bd0-8256-11d8-b7ed-b8a03c50a862

# %%
test_df.iloc[:,16:21].head(10)
# Out:
#    decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  \
# 0              NaN               NaN                            NaN
# 1              NaN               NaN                            NaN
# 2              NaN               NaN                            NaN
# 3              NaN               NaN                            NaN
# 4              NaN               NaN                            NaN
# 5              NaN               NaN                            NaN
# 6              NaN               NaN                            NaN
# 7              NaN               NaN                            NaN
# 8              NaN               NaN                            NaN
# 9              NaN               NaN                            NaN
#
#    coordinatePrecision  elevation
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                  NaN        NaN
# 3                  NaN     1600.0
# 4                  NaN        NaN
# 5                  NaN        NaN
# 6                  NaN        NaN
# 7                  NaN        NaN
# 8                  NaN        NaN
# 9                  NaN        NaN

# %%
test_df.iloc[:,21:31].head(10)
# Out:
#    elevationAccuracy  depth  depthAccuracy             eventDate   day  month  \
# 0                NaN    NaN            NaN                   NaN   NaN    NaN
# 1                NaN    NaN            NaN                   NaN   NaN    NaN
# 2                NaN    NaN            NaN                   NaN   NaN    NaN
# 3                NaN    NaN            NaN  1909-12-17T00:00:00Z  17.0   12.0
# 4                NaN    NaN            NaN  1872-10-18T00:00:00Z  18.0   10.0
# 5                NaN    NaN            NaN                   NaN   NaN    NaN
# 6                NaN    NaN            NaN  1889-07-20T00:00:00Z  20.0    7.0
# 7                NaN    NaN            NaN                   NaN   NaN    NaN
# 8                NaN    NaN            NaN                   NaN   NaN    NaN
# 9                NaN    NaN            NaN  1871-08-01T00:00:00Z   NaN    8.0
#
#      year  taxonKey  speciesKey       basisOfRecord
# 0     NaN   4258472   4258713.0  PRESERVED_SPECIMEN
# 1     NaN   4258472   4258713.0  PRESERVED_SPECIMEN
# 2     NaN   8056568   8056568.0  PRESERVED_SPECIMEN
# 3  1909.0   4258213   4258213.0  PRESERVED_SPECIMEN
# 4  1872.0   3095283   3095283.0  PRESERVED_SPECIMEN
# 5     NaN   3155905   3155905.0  PRESERVED_SPECIMEN
# 6  1889.0   4256216   2650632.0  PRESERVED_SPECIMEN
# 7     NaN   3155905   3155905.0  PRESERVED_SPECIMEN
# 8     NaN   3122039   3122039.0  PRESERVED_SPECIMEN
# 9  1871.0   3122039   3122039.0  PRESERVED_SPECIMEN

# %%
test_df.iloc[:,31:41].head(10)
# Out:
#   institutionCode         collectionCode     catalogNumber recordNumber  \
# 0               B  Herbarium Berolinense  B -W 19937 -02 0          NaN
# 1               B  Herbarium Berolinense  B -W 19937 -01 0          NaN
# 2               B  Herbarium Berolinense      B 20 0049406          NaN
# 3               B  Herbarium Berolinense      B 20 0011251          NaN
# 4               B  Herbarium Berolinense      B 10 0461080          NaN
# 5               B  Herbarium Berolinense      B 10 0630589          NaN
# 6               B  Herbarium Berolinense    B 20 0015631_b          NaN
# 7               B  Herbarium Berolinense      B 10 0630588          NaN
# 8               B  Herbarium Berolinense      B 10 0461077          NaN
# 9               B  Herbarium Berolinense      B 10 0461067          NaN
#
#                       identifiedBy  dateIdentified  license  rightsHolder  \
# 0                              NaN             NaN  CC0_1_0           NaN
# 1                              NaN             NaN  CC0_1_0           NaN
# 2                              NaN             NaN  CC0_1_0           NaN
# 3                              NaN             NaN  CC0_1_0           NaN
# 4                              NaN             NaN  CC0_1_0           NaN
# 5  P. J. M. Maas & L. J. T. Westra             NaN  CC0_1_0           NaN
# 6                              NaN             NaN  CC0_1_0           NaN
# 7  P. J. M. Maas & L. J. T. Westra             NaN  CC0_1_0           NaN
# 8                              NaN             NaN  CC0_1_0           NaN
# 9                              NaN             NaN  CC0_1_0           NaN
#
#                           recordedBy typeStatus
# 0                         Broussonet        NaN
# 1                   J. B. G. M. Bory   HOLOTYPE
# 2                        Linden,J.J.        NaN
# 3              Brade,A. & Brade,A.C.        NaN
# 4  A. H. Brotherus & V. F. Brotherus        NaN
# 5       Hostmann,F.W.R. & Kappler,A.        NaN
# 6                                  ?        NaN
# 7       Hostmann,F.W.R. & Kappler,A.        NaN
# 8                     F. Hazslinszky        NaN
# 9    xx Herbario R. Musei Florentini        NaN

# %%
test_df.iloc[:,41:46].head(10)
# Out:
#    establishmentMeans           lastInterpreted   mediaType  \
# 0                 NaN  2018-07-22T21:21:19.371Z  STILLIMAGE
# 1                 NaN  2018-07-22T21:21:19.371Z  STILLIMAGE
# 2                 NaN  2018-07-09T10:12:59.685Z  STILLIMAGE
# 3                 NaN  2018-07-07T19:13:53.330Z  STILLIMAGE
# 4                 NaN  2018-07-07T19:13:46.368Z         NaN
# 5                 NaN  2018-07-07T19:17:19.105Z  STILLIMAGE
# 6                 NaN  2018-07-22T21:22:37.961Z  STILLIMAGE
# 7                 NaN  2018-07-07T19:17:19.108Z  STILLIMAGE
# 8                 NaN  2018-07-07T19:18:04.706Z         NaN
# 9                 NaN  2018-07-22T21:19:54.025Z         NaN
#
#                    issue
# 0                    NaN
# 1                    NaN
# 2  RECORDED_DATE_INVALID
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7  RECORDED_DATE_INVALID
# 8                    NaN
# 9                    NaN

# %% [markdown]
# # Select Feature for Item Similarity

# %%
item_df = test_df[[
    'catalogNumber',
    'occurrenceID',
    'scientificName',    
    'kingdom',
    'phylum',
    'class',
    'order',
    'family',
    'genus',
    'species',
    'countryCode',
    'locality'
]]

# %%
item_df.head(10)
# Out:
#       catalogNumber                                   occurrenceID  \
# 0  B -W 19937 -02 0    http://herbarium.bgbm.org/object/BW19937020
# 1  B -W 19937 -01 0    http://herbarium.bgbm.org/object/BW19937010
# 2      B 20 0049406    http://herbarium.bgbm.org/object/B200049406
# 3      B 20 0011251    http://herbarium.bgbm.org/object/B200011251
# 4      B 10 0461080    http://herbarium.bgbm.org/object/B100461080
# 5      B 10 0630589    http://herbarium.bgbm.org/object/B100630589
# 6    B 20 0015631_b  http://herbarium.bgbm.org/object/B200015631_b
# 7      B 10 0630588    http://herbarium.bgbm.org/object/B100630588
# 8      B 10 0461077    http://herbarium.bgbm.org/object/B100461077
# 9      B 10 0461067    http://herbarium.bgbm.org/object/B100461067
#
#                             scientificName  kingdom        phylum  \
# 0          Asplenium acutum Bory ex Willd.  Plantae  Tracheophyta
# 1          Asplenium acutum Bory ex Willd.  Plantae  Tracheophyta
# 2               Diplazium rhoifolium Mett.  Plantae  Tracheophyta
# 3                Asplenium virillae Christ  Plantae  Tracheophyta
# 4       Arctanthemum arcticum (L.) Tzvelev  Plantae  Tracheophyta
# 5           Guatteria schomburgkiana Mart.  Plantae  Tracheophyta
# 6             Asplenium heufleri Reichardt  Plantae  Tracheophyta
# 7           Guatteria schomburgkiana Mart.  Plantae  Tracheophyta
# 8  Leucanthemopsis alpina (L.) V.H.Heywood  Plantae  Tracheophyta
# 9  Leucanthemopsis alpina (L.) V.H.Heywood  Plantae  Tracheophyta
#
#             class         order        family            genus  \
# 0  Polypodiopsida  Polypodiales  Aspleniaceae        Asplenium
# 1  Polypodiopsida  Polypodiales  Aspleniaceae        Asplenium
# 2  Polypodiopsida  Polypodiales   Athyriaceae        Diplazium
# 3  Polypodiopsida  Polypodiales  Aspleniaceae        Asplenium
# 4   Magnoliopsida     Asterales    Asteraceae     Arctanthemum
# 5   Magnoliopsida   Magnoliales    Annonaceae        Guatteria
# 6  Polypodiopsida  Polypodiales  Aspleniaceae        Asplenium
# 7   Magnoliopsida   Magnoliales    Annonaceae        Guatteria
# 8   Magnoliopsida     Asterales    Asteraceae  Leucanthemopsis
# 9   Magnoliopsida     Asterales    Asteraceae  Leucanthemopsis
#
#                     species countryCode  \
# 0       Asplenium onopteris          ES
# 1       Asplenium onopteris          ES
# 2      Diplazium rhoifolium          GY
# 3        Asplenium virillae          CR
# 4     Arctanthemum arcticum         NaN
# 5  Guatteria schomburgkiana          SR
# 6   Asplenium alternifolium          IT
# 7  Guatteria schomburgkiana          SR
# 8    Leucanthemopsis alpina          SK
# 9    Leucanthemopsis alpina          IT
#
#                                             locality
# 0                                         Teneriffe.
# 1                    Teneriffe a la forêt de Laguna.
# 2                                       New Granada.
# 3                          Candelaria, Alt.: 1600 m.
# 4                  Triostroff in Lapponia maxime or.
# 5                                                NaN
# 6  Rheinpreußen auf Devon Schiefer des Ahrthales....
# 7                                              Para.
# 8                                             Tatra.
# 9                Lombardei. [?] in Monte Venerocolo.

# %% [markdown]
# # Percentage of missing values

# %%
item_df.isna().sum() * 100 / len(item_df)
# Out:
# catalogNumber      0.000000
# occurrenceID       0.000000
# scientificName     0.000000
# kingdom            0.000263
# phylum             0.398658
# class              0.420221
# order              0.430477
# family             0.423114
# genus              1.391621
# species            8.549054
# countryCode       15.862952
# locality          25.323975
# dtype: float64

# %% [markdown]
# # Number of unique value

# %%
item_df.nunique()
# Out:
# catalogNumber     380276
# occurrenceID      380276
# scientificName     69657
# kingdom                4
# phylum                11
# class                 35
# order                162
# family               697
# genus               8049
# species            50746
# countryCode          221
# locality           72843
# dtype: int64
